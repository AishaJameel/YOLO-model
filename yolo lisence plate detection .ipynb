# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8 small model
model = YOLO("yolov8s.pt")

# Train the model
model.train(
    data=r"C:\Users\amnaj\Downloads\updated data for license plate\data.yml",  # path to your YAML
    epochs=20,
    imgsz=640,f
    batch=10
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.228 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.227  Python-3.13.9 torch-2.9.0+cpu CPU (AMD Ryzen 5 5500H with Radeon Graphics)
# ...
