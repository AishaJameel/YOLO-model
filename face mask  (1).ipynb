# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# %%
from tensorflow import keras
model = keras.models.load_model(r"C:\Users\amnaj\Downloads\best_mask_model.keras")

# If the model is in the same folder as notebook

print("✅ Model loaded successfully!")
# Out:
# ✅ Model loaded successfully!

# %%
input_h, input_w = model.input_shape[1], model.input_shape[2]

cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # 🔹 Resize correctly to model input size
    resized = cv2.resize(frame, (input_w, input_h))
    print("Resized shape:", resized.shape)   # check once

    normalized = resized / 255.0
    img_input = normalized.reshape(1, input_h, input_w, 3)

    prediction = model.predict(img_input)
    label = "Square" if prediction < 0.5 else "Rectangle"

    cv2.putText(frame, label, (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2)
    cv2.imshow("Shape Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Resized shape: (150, 150, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# Resized shape: (150, 150, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Resized shape: (150, 150, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Resized shape: (150, 150, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Resized shape: (150, 150, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Resized shape: (150, 150, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Resized shape: (150, 150, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Resized shape: (150, 150, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Resized shape: (150, 150, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Resized shape: (150, 150, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Resized shape: (150, 150, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Resized shape: (150, 150, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Resized shape: (150, 150, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Resized shape: (150, 150, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ...

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# Load your trained mask model
model = load_model('best_mask_model.keras')  # or .h5

# Get model input shape
input_h, input_w = model.input_shape[1], model.input_shape[2]

# Open webcam
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Resize frame to model input size
    resized = cv2.resize(frame, (input_w, input_h))
    normalized = resized / 255.0
    img_input = normalized.reshape(1, input_h, input_w, 3)

    # Predict
    prediction = model.predict(img_input)[0][0]

    # Determine label and color
    if prediction < 0.5:
        label = "Mask"
        color = (0, 255, 0)  # Green
    else:
        label = "No Mask"
        color = (0, 0, 255)  # Red

    # Display label on webcam feed
    cv2.putText(frame, f"{label} ({prediction*100:.2f}%)", (30, 50), 
                cv2.FONT_HERSHEY_SIMPLEX, 1, color, 2)
    cv2.imshow("Face Mask Detector", frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# ...
